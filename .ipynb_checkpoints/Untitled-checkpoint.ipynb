# %%
import pandas as pd

# %%
dividends_2021 = "https://nairametrics.com/2022/01/16/list-of-dividends-announced-so-far-in-2021/"
dividends_2022 = "https://nairametrics.com/2022/09/16/list-of-dividends-announced-in-2022/"

afx = "https://afx.kwayisi.org/ngx/"
afx_2 = "https://afx.kwayisi.org/ngx/?page=2"

# %%
tables_2021 = pd.read_html(afx, match="Ticker")
tables_2 = pd.read_html(afx_2, match="Ticker")

# %%
len(tables_2021)
# Out:
# 1

# %%
df2 = tables_2[0]

# %%
df
# Out:
#         Ticker                            Name     Volume    Price  Change
# 0     ABBEYBDS         Abbey Mortgage Bank Plc     5000.0     1.70    0.00
# 1     ABCTRANS          Associated Bus Company    52853.0     0.27    0.00
# 2      ACADEMY                   Academy Press   894396.0     1.31   -0.14
# 3   ACCESSCORP             Access Holdings Plc  2777240.0     8.00    0.00
# 4    AFRINSURE      African Alliance Insurance        NaN     0.20     NaN
# ..         ...                             ...        ...      ...     ...
# 95      NESTLE                  Nestle Nigeria    24067.0  1215.00    0.00
# 96    NGXGROUP         Nigerian Exchange Group  3943042.0    21.00    0.00
# 97    NIGERINS         Niger Insurance Company        NaN     0.20     NaN
# 98        NNFM    Northern Nigeria Flour Mills    21000.0     6.80    0.00
# 99      NOTORE  Notore Chemical Industries Plc        NaN    62.50     NaN
#
# [100 rows x 5 columns]

# %%
df2
# Out:
#         Ticker                               Name     Volume    Price  Change
# 0    NPFMCRFBK              NPF Microfinance Bank   256353.0     1.59    0.06
# 1      NSLTECH       Secure Electronic Technology        NaN     0.20     NaN
# 2        OANDO                          Oando Plc  2012853.0     4.48    0.00
# 3     OKOMUOIL                     Okomu Oil Palm    20453.0   169.50    0.00
# 4       OMATEK                    Omatek Ventures        NaN     0.20     NaN
# 5    PHARMDEKO                    Pharma-Deko Plc        NaN     2.05     NaN
# 6   PREMPAINTS                     Premier Paints        NaN    10.00     NaN
# 7       PRESCO                         Presco Plc    31830.0   128.35    0.00
# 8     PRESTIGE         Prestige Assurance Company        NaN     0.51     NaN
# 9           PZ                 PZ Cussons Nigeria    52486.0     8.40    0.00
# 10    RAKUNITY        RAK Unity Petroleum Company        NaN     0.30     NaN
# ...
